# %% [markdown]
# # Example of a sequence

# %% [markdown]
# ### Import

# %%
# %load_ext autoreload
# %autoreload 2
from score import *
from plots import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set up the parameters and Getting the sequence

# %%
error_add = 3
factor = 0.5
factor_sim = 3

data, get_players, raw_data = get_video(1, '05:01', 2, '../data/MIL_BOS.jsonl')
# Out:
# Size of the data is 121 frames

# %% [markdown]
# ## Get the Proba for the sequence

# %%
score_clos, stop_index, times = get_score_closeness(data, get_players, error_add = error_add)
score_sim = get_score_velocity(raw_data)
score_sim = reshape_score(score_sim, data, get_players, stop_index)
compute_proba(score_clos, score_sim, times, factor = factor, factor_sim = factor_sim)

# %% [markdown]
# ## Computing the video

# %%
save_plots_proba(data, raw_data, "../data/Frames", get_players, factor = factor, factor_sim = factor_sim, error_add = error_add)
# Out:
# Folder '../data/Frames' has been created.
# /Users/leforestierlucas/Desktop/MIT/NBA Deliverable/code/utils.py:395: RuntimeWarning: invalid value encountered in double_scalars
#   return {key: value / summing for key, value in dico.items()}
# 3D Plots saved in folder: ../data/Frames

# %%
create_video("../data/Frames", "../data/video", fps = 10)
